# %%
import pandas as pd
df_activities = pd.read_csv("cardioActivities.csv")
df_activities.head(2)
# Out:
#                   Date                           Activity Id     Type  \
# 0  2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1  2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
#
#   Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 0        NaN          10.44    58:40         5:37                 10.68
# 1        NaN          12.84  1:14:12         5:47                 10.39
#
#    Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 0            774.0        130                     159.0              NaN
# 1            954.0        168                     159.0              NaN
#
#   Notes               GPX File
# 0   NaN  2018-11-11-140512.gpx
# 1   NaN  2018-11-09-150235.gpx

# %%
col_to_drop = df_activities.drop(['Route Name',"Friend's Tagged","Notes"],axis =1,inplace = True)

# %%
df_activities['Type'].value_counts()
# Out:
# Running    459
# Cycling     29
# Walking     18
# Other        2
# Name: Type, dtype: int64

# %%
#['foo', 'fuz', np.nan]).str.replace('f.', 'ba', regex=True)
df_activities["Type"]= df_activities["Type"].replace('Other', "Unicycling") 
df_activities.head(20)
# Out:
#                    Date                           Activity Id        Type  \
# 0   2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15     Running
# 1   2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7     Running
# 2   2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c     Running
# 3   2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36     Running
# 4   2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438     Running
# 5   2018-10-19 17:52:32  fe2cb3fc-6330-40fa-8a92-0f86f4e72282     Running
# 6   2018-10-14 17:28:56  96acedc9-d3d5-4aac-8df4-f549a6418c1d     Running
# 7   2018-10-12 17:41:58  3c91092b-e6f3-4565-b540-6b6537358006     Running
# 8   2018-10-06 16:45:02  4c163abe-3a57-42fd-b50b-7f365960cbd4     Cycling
# 9   2018-09-30 16:52:34  70c7f2ba-f4cb-4403-a9e4-bf2c9b93bb05     Running
# 10  2018-09-16 14:55:03  30aaa821-1d3a-4f2f-9688-8543cebbd6e8     Cycling
# 11  2018-09-02 17:24:28  51781e97-560e-48d0-9522-44f303f9235f  Unicycling
# ...

# %%
df_activities.isnull().sum()
# Out:
# Date                          0
# Activity Id                   0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# GPX File                      4
# dtype: int64

# %%
print("boolean Df", df_activities.isnull()) 
print("\n total NaN at each column in a df:",df_activities.isnull().sum())
# Out:
# boolean Df       Date  Activity Id   Type  Distance (km)  Duration  Average Pace  \
# 0    False        False  False          False     False         False
# 1    False        False  False          False     False         False
# 2    False        False  False          False     False         False
# 3    False        False  False          False     False         False
# 4    False        False  False          False     False         False
# ..     ...          ...    ...            ...       ...           ...
# 503  False        False  False          False     False         False
# 504  False        False  False          False     False         False
# 505  False        False  False          False     False         False
# 506  False        False  False          False     False         False
# 507  False        False  False          False     False         False
#
#      Average Speed (km/h)  Calories Burned  Climb (m)  \
# 0                   False            False      False
# ...
